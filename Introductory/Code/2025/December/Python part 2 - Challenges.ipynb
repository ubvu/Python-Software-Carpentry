# %% [markdown]
# # for loop

# %% [markdown]
# **Challenge 1 - From 1 to N**
#
# Python has a built-in function called range that generates a sequence of numbers. range can accept 1, 2, or 3 parameters.
#
# - If one parameter is given, range generates a sequence of that length, starting at zero and incrementing by 1. For example, ```range(3)``` produces the numbers 0, 1, 2.
# - If two parameters are given, range starts at the first and ends just before the second, incrementing by one. For example, ```range(2, 5)``` produces 2, 3, 4.
# - If range is given 3 parameters, it starts at the first one, ends just before the second one, and increments by the third one. For example, ```range(3, 10, 2)``` produces 3, 5, 7, 9.
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><b>Using range, write a loop that prints the first 3 natural numbers: </b><i>Click for answer</i></summary>
#
#
#     for number in range(1, 4):
#         print(number)

# %% [markdown]
# **Challenge 2 - Understanding the loops 1**
#
# Given the following loop:
#
# ```
# elements = ['oxygen', 'hydrogen', 'helium']
# for element in elements:
#     print(element)
# ```
#
#
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><b>How many times is the body of the loop executed? </b><i>Click for answer</i></summary>
#     The body of the loop is executed 3 times. Once for each element in the list.
#     </div>

# %% [markdown]
# **Challenge 3 - Understanding the loops 2**
#
# Given the following loop:
#
# ```
# word = 'oxygen'
# for letter in word:
#     print(letter)
# ```
#
#
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><b>How many times is the body of the loop executed? </b><i>Click for answer</i></summary>
#     The body of the loop is executed 6 times. Once for each letter in the string.
#     </div>

# %% [markdown]
# **Challenge 4 - Summing a list**
#
# Write a loop that calculates the sum of elements in a list by adding each element and printing the final value, so ```[124, 402, 36]``` prints 562.
#
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><b> </b><i>Click for answer</i></summary>
#
#     numbers = [124, 402, 36]
#     summed = 0
#     for num in numbers:
#         summed = summed + num
#     print(summed)
#
# </div>

# %% [markdown]
# # Analyzing Data from Multiple Files

# %% [markdown]
# **Challenge 1  - Plotting Differences**
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary>
# Plot the difference between the average inflammations reported in the first and second datasets (stored in inflammation-01.csv and inflammation-02.csv, correspondingly), i.e., the difference between the leftmost plots of the first two figures.
#
# <i>Click for answer</i></summary>
#
#
#     import glob
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     filenames = sorted(glob.glob('inflammation*.csv'))
#
#     data0 = np.loadtxt(fname=filenames[0], delimiter=',')
#     data1 = np.loadtxt(fname=filenames[1], delimiter=',')
#
#     plt.ylabel('Difference in average')
#     plt.plot(np.mean(data0, axis=0) - np.mean(data1, axis=0))
#
#     plt.tight_layout()
#
#
# </div>

# %% [markdown]
# # Making Choices

# %% [markdown]
# **Challenge 1  - How Many Paths?**
#
# Consider this code:
#
# ```
# if 4 > 5:
#     print('A')
# elif 4 == 5:
#     print('B')
# elif 4 < 5:
#     print('C')
# ```
#
#
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><b>Which of the following would be printed if you were to run this code? Why did you pick this answer?
#
# A <br>
# B <br>
# C <br>
# B and C <br>
#
# </b><i>Click for answer</i></summary>
# C gets printed because the first two conditions, ```4 > 5``` and ```4 == 5```, are not true, but ```4 < 5``` is true. In this case only one of these conditions can be true for at a time, but in other scenarios multiple elif conditions could be met. In these scenarios only the action associated with the first true elif condition will occur, starting from the top of the conditional section. (For a more eleborate you can check the solution for this excersize on the following [webpage](https://swcarpentry.github.io/python-novice-inflammation/07-cond.html).)
#     </div>

# %% [markdown]
# **Challenge 2  - Too much cake at the office**
#
# In a growing and increasingly successful research group, the amount of cake at the office is getting out of hand. Where in the early days of the group it was nice people brought cake for their birthday, both first & co-authored publications, new arrivals, leaving colleagues, birthdays of family members etc. Now it is getting out of hand.
#
# It is your task to update the tool, that a colleague, who left the group, created. To add the following: <br>
#     1. If the occasion is in the weekend don't bring cake. <br>
#     2. Because people might be confused by this new rule, include something informative in the printed message to remind them of this new agreement. <br>
#
#     first_to_initiate = True # Select if you're the first to suggest to bring cake on the respective day
#     weeks_since_bringing_cake = 7 # Indicate the amount of weeks since the last day you brougth cake
#
#     if first_to_initiate and (weeks_since_bringing_cake>6):
#         print('If you feel like it bring cake to the office :) ')
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><i>Click for answer</i></summary>
#
#
#     weekend = True # Set to False when it's a weekday and set to True when it is the weekend.
#     first_to_initiate = True # Select if you're the first to suggest to bring cake on the respective day
#     weeks_since_bringing_cake = 7 # Indicate the amount of weeks since the last day you brougth cake
#
#     if first_to_initiate and (weeks_since_bringing_cake>6):
#         if weekend:
#             print('Congratulations! We will celebrate without cake, because it is weekend ;) ')
#         else:
#             print('If you feel like it bring cake to the office :) ')
#
# </div>

# %% [markdown]
# **Challenge 3  - Counting Vowels**
#
# Write a loop that counts the number of vowels in a character string. <br>
# Test it on a few individual words and full sentences. <br>
# Once you are done, compare your solution to your neighbor’s. <br>
# Did you make the same decisions about how to handle the letter ‘y’ (which some people think is a vowel, and some do not)?
#
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><i>Click for answer</i></summary>
#
#     vowels = 'aeiouAEIOU'
#     sentence = 'Mary had a little lamb.'
#     count = 0
#     for char in sentence:
#         if char in vowels:
#             count += 1
#
#     print('The number of vowels in this string is ' + str(count))
#
# </div>

# %% [markdown]
# **Challenge 4  - Too much cake at the office - part 2**
#
# It has been some time since the last <i>cake tool</i> update. You think it needs some further adjustments. Thinks of some adjustments and implement them.
#
# <div class=\"alert alert-success\">
#     <details>
#     <summary><i>Click for inspiration</i></summary>
#
# One could add a scale of how much a event is worth of being celebrated with cake and make that a part of the tool.
#
# </div>

# %% [markdown]
# # Combining everything up to now

# %% [markdown]
# To get an overview of the different datasets. We're going to make a figure including a subplot for each data set, showing the mean, minimum and maximum inflammation per day across the patients. We will generate this plot step by step. Take a deep dive in a try without guidance or follow the following steps.

# %%
# Step 1: list all the inflammation files and select a subset of 3 to experiment with for the testing phase by using an if-statement

# %%
# Step 2: load the data of the first file

# %%
# Step 3: Create a plot with the mean, minimum and maximum inside. (To create a dashed line one can use linestyle='--' and ':' for a dotted line.)

# %%
# Step 4: Create a for loop that this plot for subset of files

# %%
# Step 5: Edit the code so instead of plots, subplots are created in one figure

# %%
# Step 6: add tight_layout() to the code to make plot cleaner

# %%
# Step 7: Add a title to each subplot

# %%
# Step 8: Set the x-axis from 0 to 40

# %%
# Step 9: Add labels to the axis

# %%
# Step 10: Add a legend

# %%
# Step 11: Update the code so the data for all 12 data sets will be plotted

# %%
# Step 12: One legend would be enough. Use an if-statement to reduce the number of legends to one.

# %%
# Step 13: There still seems a lot of unnecessary duplication in labels. Reduce this appropriately by making use of the of if-statements.

# %%
# Step 14: It is time to save the figure

# %% [markdown]
# <div class=\"alert alert-success\">
#     <details>
#     <summary><i>Click for a possible answer.</i></summary>
#
#     path = 'data/'
#     fname = 'inflammation-*.csv'
#     fpaths = glob.glob(path + fname)
#
#     sample = False
#
#     if sample:
#         fpaths = fpaths[0:3]
#
#     fig = plt.figure(figsize=(18,9))
#     for ki in np.arange(1, 13):
#         filename = fpaths[ki-1]
#         data = np.loadtxt(fname=filename, delimiter=',')
#         axis = fig.add_subplot(3, 4, ki)
#         axis.set_title('Inflammation ' + str(ki))
#         axis.plot(np.mean(data, axis=0), label='mean')
#         axis.plot(np.max(data, axis=0), label='max', linestyle='--')
#         axis.plot(np.min(data, axis=0), label='min', linestyle=':')
#         axis.set_xlim([0,40])
#         if ki > 8:
#              axis.set_xlabel('Day')
#         if ki == 1 or ki ==5 or ki == 9:
#             axis.set_ylabel('Infection level')
#         if ki == 12:
#             axis.legend()
#
#     fig.tight_layout()
#     plt.savefig(path + 'inflammation_overview.png')
#
#
# </div>
