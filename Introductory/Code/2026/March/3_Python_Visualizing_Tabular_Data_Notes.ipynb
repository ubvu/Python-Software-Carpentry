# %%
import numpy
data = numpy.loadtxt(fname='./data/inflammation-01.csv', delimiter=',')
import matplotlib.pyplot

# %%
matplotlib.pyplot.imshow(data)
matplotlib.pyplot.colorbar()

# %%
ave_inflammation = numpy.mean(data, axis=0)
ave_plot = matplotlib.pyplot.plot(ave_inflammation)

# %%
matplotlib.pyplot.plot(ave_inflammation, marker='o', linestyle='None')

# %%
matplotlib.pyplot.scatter(range(len(ave_inflammation)), ave_inflammation)

# %%
max_inflammation = numpy.amax(data, axis=0)
max_plot = matplotlib.pyplot.plot(max_inflammation)

# %%
min_inflammation = numpy.amin(data, axis=0)
min_plot = matplotlib.pyplot.plot(min_inflammation)

# %%
fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1,3,1)
axes2 = fig.add_subplot(1,3,2)
axes3 = fig.add_subplot(1,3,3)

axes1.set_ylabel('average inflammation')
axes1.set_title('average inflammation per day')
axes1.set_xlabel('time (days)')
axes1.plot(ave_inflammation)

axes2.set_ylabel('max inflammation')
axes2.set_title('max inflammation per day')
axes2.set_xlabel('time (days)')
axes2.plot(max_inflammation)

axes3.set_ylabel('min inflammation')
axes3.set_title('min inflammation per day')
axes3.set_xlabel('time (days)')
axes3.plot(min_inflammation)

fig.tight_layout()

matplotlib.pyplot.savefig('inflammation_summary.png')
