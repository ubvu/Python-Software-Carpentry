# %%
# This is our carpentries file
# shortcut to comment is ctrl + /
# The jupyter notebook is operated from your browser, but it doesn't require an internet connection
# Find the etherpad from this lesson here: https://pad.carpentries.org/2025-11-11-Aurora
# This course is based on: https://swcarpentry.github.io/python-novice-inflammation/

# %%
# Let's start off with some arithmetic
3 + 7
# Out:
# 10

# %%
10 - 9
# Out:
# 1

# %%
# Divide
13 / 5
# Out:
# 2.6

# %%
# Multiply
5 * 9
# Out:
# 45

# %%
# in Python we use "=" to assign a variable a value
weight_kg = 60.3
print(weight_kg)
# Out:
# 60.3

# %%
# naming conventions for variables
# Snake case is  like_this, this_is_my_variable
# Camel case is likeThis, thisIsMyVariable
# bad variable name: this_is_the_weight_i_can_lift_today, too long

# %%
location = "uni gym"
print(location)
# Out:
# uni gym

# %%
# including quotes
quote_text = '"this is a quote"'
print(quote_text)
# Out:
# "this is a quote"

# %%
weight_lb = 2.2 * weight_kg

# %%
lift_info = "October, " + location
print(weight_lb)
print(lift_info)
# Out:
# 132.66
# October, uni gym

# %%
# You can print them all in one command
print("weight in pounds: ", weight_lb, lift_info)
# Out:
# weight in pounds:  132.66 October, uni gym

# %%
print(type(60), type(60.3))
print(type(lift_info))
# Out:
# <class 'int'> <class 'float'>
# <class 'str'>

# %%
# I got stronger, the new weight I cna lift is 65kg
weight_kg = 65
print("new PB: ", weight_kg)
# Recalculate the weight in pounds
weight_lb = 2.2 * weight_kg
print(weight_lb)
# Out:
# new PB:  65
# 143.0

# %%
# What does this print out?
first, second = "grace", "hopper"
third, fourth = second, first
# print(first, second, third, fourth)

# %%
# What data types are these?
planet = "Earth"
apples = 5
distance = 10.5
# print(type(planet), type(apples), type(distance))
